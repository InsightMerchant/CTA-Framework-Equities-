# %%
import pandas as pd

df = pd.read_parquet("data/raw/spy.parquet")

# %%
df.head()
# Out:
#      code              name             time_key       open      close  \
# 0  US.SPY  SPDR S&P 500 ETF  2023-01-03 09:41:00  429.31794  429.67564
# 1  US.SPY  SPDR S&P 500 ETF  2023-01-03 09:42:00  429.65794  430.03794
# 2  US.SPY  SPDR S&P 500 ETF  2023-01-03 09:43:00  430.05794  430.09294
# 3  US.SPY  SPDR S&P 500 ETF  2023-01-03 09:44:00  430.10794  429.88794
# 4  US.SPY  SPDR S&P 500 ETF  2023-01-03 09:45:00  429.88794  429.20794
#
#         high        low  pe_ratio  turnover_rate    volume      turnover  \
# 0  429.71214  429.11794       0.0            0.0  284993.0  1.098415e+08
# 1  430.14784  429.65794       0.0            0.0  390764.0  1.508399e+08
# 2  430.35794  430.03794       0.0            0.0  335230.0  1.294856e+08
# 3  430.20794  429.86794       0.0            0.0  279990.0  1.081110e+08
# 4  430.03794  429.09344       0.0            0.0  338855.0  1.306818e+08
#
#    change_rate  last_close
# 0     0.083318   429.31794
# 1     0.084319   429.67564
# ...

# %%
df['datetime'] = pd.to_datetime(df['time_key'])
df = df[df["datetime"] >= "2023-01-04 09:45:00"]

# %%
df.head(20)
# Out:
#        code              name             time_key       open      close  \
# 394  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:45:00  427.40794  426.54784
# 395  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:46:00  426.52794  426.50794
# 396  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:47:00  426.49794  426.60794
# 397  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:48:00  426.59794  426.75794
# 398  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:49:00  426.75794  426.75794
# 399  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:50:00  426.78794  426.63784
# 400  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:51:00  426.63794  426.84794
# 401  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:52:00  426.85794  426.57794
# 402  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:53:00  426.56794  426.62794
# 403  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:54:00  426.62794  426.74794
# 404  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:55:00  426.69794  426.78794
# 405  US.SPY  SPDR S&P 500 ETF  2023-01-04 09:56:00  426.76794  426.94794
# ...

# %%
n = (20,401,10)
params_signal = {
    
    'zscore': np.arange(-3, 3.1, 0.1),
    'minmax': np.arange(-1, 1.1, 0.1),
    'xxx'.....
    ...
    ...
    ...
}
